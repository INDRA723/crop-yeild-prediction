# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crop_data=pd.read_csv(r"C:\Users\ACT-19\Downloads\Crop-Yield-Prediction-in-India-using-ML-main\Crop-Yield-Prediction-in-India-using-ML-main\crop_production.csv")
crop_data
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 0      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 1      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 2      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 3      Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 4      Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# ...                            ...           ...        ...          ...
# 15826                        Assam       DHEMAJI     2010.0  Rabi
# 15827                        Assam       DHEMAJI     2010.0  Rabi
# 15828                        Assam       DHEMAJI     2010.0  Rabi
# 15829                        Assam       DHEMAJI     2010.0  Rabi
# 15830                        Assam           NaN        NaN          NaN
#
#                         Crop     Area  Production
# 0                   Arecanut   1254.0      2000.0
# 1        Other Kharif pulses      2.0         1.0
# 2                       Rice    102.0       321.0
# 3                     Banana    176.0       641.0
# 4                  Cashewnut    720.0       165.0
# ...                      ...      ...         ...
# 15826                 Masoor     92.0        38.0
# 15827      Moong(Green Gram)    229.0       128.0
# 15828  Peas & beans (Pulses)    474.0       301.0
# 15829      Rapeseed &Mustard  16800.0      8214.0
# 15830                    NaN      NaN         NaN
#
# [15831 rows x 7 columns]

# %%
crop_data.shape
# Out:
# (15831, 7)

# %%
crop_data.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %%
crop_data.describe()
# Out:
#           Crop_Year           Area    Production
# count  15830.000000   15830.000000  1.576000e+04
# mean    2006.075237    9677.251678  1.168658e+06
# std        5.125498   37736.103854  2.183598e+07
# min     1997.000000       0.200000  0.000000e+00
# 25%     2002.000000     126.000000  1.957500e+02
# 50%     2006.000000     727.000000  1.251000e+03
# 75%     2011.000000    4000.000000  8.794000e+03
# max     2014.000000  877029.000000  7.801620e+08

# %%
crop_data.isnull().sum()
# Out:
# State_Name        0
# District_Name     1
# Crop_Year         1
# Season            1
# Crop              1
# Area              1
# Production       71
# dtype: int64

# %%
crop_data = crop_data.dropna()
crop_data
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 0      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 1      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 2      Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 3      Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 4      Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# ...                            ...           ...        ...          ...
# 15825                        Assam       DHEMAJI     2010.0  Rabi
# 15826                        Assam       DHEMAJI     2010.0  Rabi
# 15827                        Assam       DHEMAJI     2010.0  Rabi
# 15828                        Assam       DHEMAJI     2010.0  Rabi
# 15829                        Assam       DHEMAJI     2010.0  Rabi
#
#                         Crop     Area  Production
# 0                   Arecanut   1254.0      2000.0
# 1        Other Kharif pulses      2.0         1.0
# 2                       Rice    102.0       321.0
# 3                     Banana    176.0       641.0
# 4                  Cashewnut    720.0       165.0
# ...                      ...      ...         ...
# 15825                Linseed     36.0        18.0
# 15826                 Masoor     92.0        38.0
# 15827      Moong(Green Gram)    229.0       128.0
# 15828  Peas & beans (Pulses)    474.0       301.0
# 15829      Rapeseed &Mustard  16800.0      8214.0
#
# [15760 rows x 7 columns]

# %%
crop_data.isnull().values.any()
# Out:
# False

# %%
crop_data.State_Name.unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam'], dtype=object)

# %%
crop_data['Yield'] = (crop_data['Production'] / crop_data['Area'])
crop_data.head(10)
# Out:
# C:\Users\ACT-19\AppData\Local\Temp\ipykernel_15388\2823116411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crop_data['Yield'] = (crop_data['Production'] / crop_data['Area'])
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS     2000.0  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 5  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 6  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 7  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 8  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
# 9  Andaman and Nicobar Islands      NICOBARS     2000.0  Whole Year
#
#                   Crop     Area  Production        Yield
# 0             Arecanut   1254.0      2000.0     1.594896
# 1  Other Kharif pulses      2.0         1.0     0.500000
# 2                 Rice    102.0       321.0     3.147059
# 3               Banana    176.0       641.0     3.642045
# 4            Cashewnut    720.0       165.0     0.229167
# 5             Coconut   18168.0  65100000.0  3583.223250
# 6           Dry ginger     36.0       100.0     2.777778
# 7            Sugarcane      1.0         2.0     2.000000
# 8         Sweet potato      5.0        15.0     3.000000
# 9              Tapioca     40.0       169.0     4.225000

# %%
dummy = pd.get_dummies(data)
dummy
# Out:
#        Crop_Year     Area  Production     Yield  District_Name_ANANTAPUR  \
# 0         2000.0   1254.0      2000.0  1.594896                    False
# 1         2000.0      2.0         1.0  0.500000                    False
# 2         2000.0    102.0       321.0  3.147059                    False
# 3         2000.0    176.0       641.0  3.642045                    False
# 4         2000.0    720.0       165.0  0.229167                    False
# ...          ...      ...         ...       ...                      ...
# 15825     2010.0     36.0        18.0  0.500000                    False
# 15826     2010.0     92.0        38.0  0.413043                    False
# 15827     2010.0    229.0       128.0  0.558952                    False
# 15828     2010.0    474.0       301.0  0.635021                    False
# 15829     2010.0  16800.0      8214.0  0.488929                    False
#
#        District_Name_ANJAW  District_Name_BAKSA  District_Name_BARPETA  \
# 0                    False                False                  False
# 1                    False                False                  False
# 2                    False                False                  False
# 3                    False                False                  False
# 4                    False                False                  False
# ...                    ...                  ...                    ...
# 15825                False                False                  False
# 15826                False                False                  False
# 15827                False                False                  False
# 15828                False                False                  False
# 15829                False                False                  False
#
#        District_Name_BONGAIGAON  District_Name_CACHAR  ...  Crop_Tapioca  \
# 0                         False                 False  ...         False
# 1                         False                 False  ...         False
# 2                         False                 False  ...         False
# 3                         False                 False  ...         False
# 4                         False                 False  ...         False
# ...                         ...                   ...  ...           ...
# 15825                     False                 False  ...         False
# 15826                     False                 False  ...         False
# 15827                     False                 False  ...         False
# 15828                     False                 False  ...         False
# 15829                     False                 False  ...         False
#
#        Crop_Tobacco  Crop_Tomato  Crop_Turmeric  Crop_Urad  Crop_Varagu  \
# 0             False        False          False      False        False
# 1             False        False          False      False        False
# 2             False        False          False      False        False
# 3             False        False          False      False        False
# 4             False        False          False      False        False
# ...             ...          ...            ...        ...          ...
# 15825         False        False          False      False        False
# 15826         False        False          False      False        False
# 15827         False        False          False      False        False
# 15828         False        False          False      False        False
# 15829         False        False          False      False        False
#
#        Crop_Wheat  Crop_other fibres  Crop_other misc. pulses  \
# 0           False              False                    False
# 1           False              False                    False
# 2           False              False                    False
# 3           False              False                    False
# 4           False              False                    False
# ...           ...                ...                      ...
# 15825       False              False                    False
# 15826       False              False                    False
# 15827       False              False                    False
# 15828       False              False                    False
# 15829       False              False                    False
#
#        Crop_other oilseeds
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 15825                False
# 15826                False
# 15827                False
# 15828                False
# 15829                False
#
# [15760 rows x 127 columns]

# %%
from sklearn.model_selection import train_test_split

x = dummy.drop(["Production","Yield"], axis=1)
y = dummy["Production"]

# Splitting data set - 25% test dataset and 75% 

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=5)

print("x_train :",x_train.shape)
print("x_test :",x_test.shape)
print("y_train :",y_train.shape)
print("y_test :",y_test.shape)
# Out:
# x_train : (11820, 125)
# x_test : (3940, 125)
# y_train : (11820,)
# y_test : (3940,)

# %%
print(x_train)
print(y_train)
# Out:
#        Crop_Year     Area  District_Name_ANANTAPUR  District_Name_ANJAW  \
# 5187      2008.0   1674.0                    False                False
# 14301     2010.0     92.0                    False                False
# 8841      2005.0    773.0                    False                False
# 11123     2003.0   1050.0                    False                False
# 12438     2006.0  52195.0                    False                False
# ...          ...      ...                      ...                  ...
# 3070      2011.0  55286.0                    False                False
# 9986      2001.0    477.0                    False                False
# 4111      1999.0   6809.0                    False                False
# 2271      2009.0    510.0                    False                False
# 2939      2008.0   2106.0                    False                False
#
#        District_Name_BAKSA  District_Name_BARPETA  District_Name_BONGAIGAON  \
# 5187                 False                  False                     False
# 14301                False                  False                     False
# 8841                 False                  False                     False
# 11123                False                  False                     False
# 12438                 True                  False                     False
# ...                    ...                    ...                       ...
# 3070                 False                  False                     False
# 9986                 False                  False                     False
# 4111                 False                  False                     False
# 2271                 False                  False                     False
# 2939                 False                  False                     False
#
#        District_Name_CACHAR  District_Name_CHANGLANG  District_Name_CHIRANG  \
# 5187                  False                    False                  False
# 14301                  True                    False                  False
# 8841                  False                    False                  False
# 11123                 False                    False                  False
# 12438                 False                    False                  False
# ...                     ...                      ...                    ...
# 3070                  False                    False                  False
# 9986                  False                     True                  False
# 4111                  False                    False                  False
# 2271                  False                    False                  False
# 2939                  False                    False                  False
#
#        ...  Crop_Tapioca  Crop_Tobacco  Crop_Tomato  Crop_Turmeric  Crop_Urad  \
# 5187   ...         False         False        False          False      False
# 14301  ...         False         False        False          False      False
# 8841   ...         False         False        False          False       True
# 11123  ...         False         False        False          False      False
# 12438  ...         False         False        False          False      False
# ...    ...           ...           ...          ...            ...        ...
# 3070   ...         False         False        False          False       True
# 9986   ...         False         False        False          False      False
# 4111   ...         False         False        False          False      False
# 2271   ...         False         False        False          False      False
# 2939   ...         False         False        False          False      False
#
#        Crop_Varagu  Crop_Wheat  Crop_other fibres  Crop_other misc. pulses  \
# 5187         False       False              False                    False
# 14301        False       False              False                    False
# 8841         False       False              False                    False
# 11123        False       False              False                    False
# 12438        False       False              False                    False
# ...            ...         ...                ...                      ...
# 3070         False       False              False                    False
# 9986         False       False              False                    False
# 4111         False       False              False                    False
# 2271         False       False              False                    False
# 2939         False       False              False                    False
#
#        Crop_other oilseeds
# 5187                 False
# 14301                False
# 8841                 False
# 11123                False
# 12438                False
# ...                    ...
# 3070                 False
# 9986                 False
# 4111                 False
# 2271                 False
# 2939                 False
#
# [11820 rows x 125 columns]
# 5187     41274.0
# 14301       34.0
# 8841       266.0
# 11123      840.0
# 12438    67915.0
#           ...
# 3070     60759.0
# 9986      2242.0
# 4111     13223.0
# 2271       601.0
# 2939      1497.0
# Name: Production, Length: 11820, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr_predict = model.predict(x_test)
lr_predict
# Out:
# array([  119866.13902275,  -625589.20834711,   -65826.64283516, ...,
#        -2148102.10092373, -1240943.70230716,   956147.67098287])

# %%
model.score(x_test,y_test)
# Out:
# 0.15825587726682355

# %%
from sklearn.metrics import r2_score
r = r2_score(y_test,lr_predict)
print("R2 score : ",r)
# Out:
# R2 score :  0.15825587726682355

# %%
plt.scatter(y_test,lr_predict)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 11)
model.fit(x_train,y_train)
rf_predict = model.predict(x_test)
rf_predict
# Out:
# array([2.42181818e+02, 4.27708182e+04, 2.73636364e+01, ...,
#        5.20000000e+01, 5.13272727e+02, 8.30090909e+02])

# %%
model.score(x_test,y_test)
# Out:
# 0.9891495873701003

# %%
from sklearn.metrics import r2_score
r1 = r2_score(y_test,rf_predict)
print("R2 score : ",r1)
# Out:
# R2 score :  0.9891495873701003

# %%
Adjr2_1 = 1 - (1-r)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
print("Adj. R-Squared : {}".format(Adjr2_1))
# Out:
# Adj. R-Squared : 0.13066856333351284

# %%
ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
sns.distplot(rf_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
plt.title('Random Forest Regression')
# Out:
# C:\Users\ACT-19\AppData\Local\Temp\ipykernel_15388\551929062.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
# C:\Users\ACT-19\AppData\Local\Temp\ipykernel_15388\551929062.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(rf_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
# Text(0.5, 1.0, 'Random Forest Regression')

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 5)
regressor.fit(x_train,y_train)

# Predicting results
decisiontree_predict = regressor.predict(x_test)
decisiontree_predict
# Out:
# array([2.25e+02, 4.32e+04, 3.00e+01, ..., 5.80e+01, 1.74e+02, 8.67e+02])

# %%
regressor.score(x_test,y_test)
# Out:
# 0.9843232092757412

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,decisiontree_predict)
print("R2 score : ",r2)
# Out:
# R2 score :  0.9843232092757412

# %%
Adjr2_2 = 1 - (1-r)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
print("Adj. R-Squared : {}".format(Adjr2_2))
# Out:
# Adj. R-Squared : 0.13066856333351284

# %%
ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
sns.distplot(decisiontree_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
plt.title('Decision Tree Regression')
# Out:
# C:\Users\ACT-19\AppData\Local\Temp\ipykernel_15388\697514152.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
# C:\Users\ACT-19\AppData\Local\Temp\ipykernel_15388\697514152.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(decisiontree_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
# Text(0.5, 1.0, 'Decision Tree Regression')

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = model, X = x_train, y=y_train, cv = 10)

# %%
a1 = (accuracies.mean()*100)
b1 = (accuracies.std()*100)

# %%
print("Accuracy : {:.2f}%".format (accuracies.mean()*100))
print("Standard Deviation : {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy : 92.14%
# Standard Deviation : 10.59%

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# create a dataset
Algorithms = ['Random Forest', 'Decision-tree']
Accuracy = [Adjr2_1, Adjr2_2]

x_pos = np.arange(len(Accuracy))

# Create bars with different colors
plt.bar(x_pos, Accuracy, color=['#488AC7','#ff8c00'])

# Create names on the x-axis
plt.xticks(x_pos, Algorithms)
plt.ylabel('Adjusted R-Squared Score')
plt.xlabel('Machine Learning Regression Techniques')

# Show graph
plt.show()
plt.savefig('SD.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# create a dataset
Algorithms = ['Random Forest', 'Decision-tree']
Accuracy = [r1, r2]

x_pos = np.arange(len(Accuracy))

# Create bars with different colors
plt.bar(x_pos, Accuracy, color=['#488AC7','#ff8c00'])

# Create names on the x-axis
plt.xticks(x_pos, Algorithms)
plt.ylabel('R-Squared Score')
plt.xlabel('Machine Learning Regression Techniques')

# Show graph
plt.show()
plt.savefig('SD.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# create a dataset
Algorithms = ['Random Forest', 'Decision-tree']
Accuracy = [Adjr2_1, Adjr2_2]

x_pos = np.arange(len(Accuracy))

# Create bars with different colors
plt.bar(x_pos, Accuracy, color=['#488AC7','#ff8c00'])

# Create names on the x-axis
plt.xticks(x_pos, Algorithms)
plt.ylabel('Standard Deviation(in %)')
plt.xlabel('Machine Learning Regression Techniques')

# Show graph
plt.show()
plt.savefig('SD.png')
